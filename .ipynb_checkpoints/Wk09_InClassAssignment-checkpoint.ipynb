# %% [markdown]
# #### In Class Assignment
#
# ##### Angela Spencer 11/10/21

# %% [markdown]
# 1. Use this article to answer the following questions:
# https://realpython.com/numpy-scipy-pandas-correlation-python/
#
# a. In a jupyter notebook markdown cell, describe the difference between linear and
# rank correlation.

# %% [markdown]
# Linear correlation compares data to a linear function. The correlation measures the proximity of the data to the linear function.
#
# Rank correlation compares data to other variables in the data and so the correclation is measured in how the data relates to other data points.

# %% [markdown]
# b. Create a scatter plot showing the relationship between
# calculated_host_listings_count and availability_365 in the Belize Airbnb data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
belize = pd.read_csv("belize_airbnb_listings.csv")

# %%
sns.scatterplot(x="calculated_host_listings_count", y="availability_365", data=belize)
plt.show()

# %% [markdown]
# c. Calculate the correlation coefficient for the data in the scatter plot, and describe
# what is happening.

# %%
belize['calculated_host_listings_count'].corr(belize["availability_365"])
# Out:
# 0.1727550292269892

# %% [markdown]
# The correlation coefficient shows the strength of the relationship between the two variables, there is a positive and very small correlation between availability and number of listings of the host.

# %% [markdown]
# 2. Create a box and whisker plot for the Belize Airbnb data price. In a markdown cell,
# describe what is going on in as simple of terms as possible. Use the documentation: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html

# %%
sns.catplot(y= 'price', data=belize, kind="box")
plt.show()

# %% [markdown]
# This graph shows the average price with whiskers indicating the interquartile range of Q3 - Q1. This setting for whiskers can be modified to include the minimum and maximum data points.
